# %% [markdown]
# <h1> Master </h1>

# %% [markdown]
# <h3> Imports</h3>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.io as sio
from scipy.io import loadmat

# %% [markdown]
# <h2> Making the machinelearning dataset

# %% [markdown]
# <h3> Read files </h3>

# %% [markdown]
# <h4>3 Moduel level

# %%
#Mixed cells

#aged

#r0
M1_mixed_aged_0_10 = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_0/T_10/M1_Mixed_Aged_R0_T10.mat', struct_as_record=True, simplify_cells=True)
M1_mixed_aged_0_25 = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_0/T_25/M1_Mixed_Aged_R0_T25.mat', struct_as_record=True, simplify_cells=True)
M1_mixed_aged_0_40 = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_0/T_40/M1_Mixed_Aged_R0_T40.mat', struct_as_record=True, simplify_cells=True)

#r1
M2_mixed_aged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_1/T_10/M2_Mixed_Aged_R1_T10.mat', struct_as_record=True, simplify_cells=True)
M2_mixed_aged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_1/T_25/M2_Mixed_Aged_R1_T25.mat', struct_as_record=True, simplify_cells=True)
M2_mixed_aged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_1/T_40/M2_Mixed_Aged_R1_T40.mat', struct_as_record=True, simplify_cells=True)

#r3
M2_mixed_aged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_3/T_10/M2_Mixed_Aged_R3_T10.mat', struct_as_record=True, simplify_cells=True)
M1_mixed_aged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_3/T_25/M1_Mixed_Aged_R3_T25.mat', struct_as_record=True, simplify_cells=True)
M2_mixed_aged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Aged/R_3/T_40/M2_Mixed_Aged_R3_T40.mat', struct_as_record=True, simplify_cells=True)

#unaged

#r0
M1_mixed_unaged_0_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_0/T_10/M1_Mixed_Unaged_R0_T10.mat', struct_as_record=True, simplify_cells=True)
M1_mixed_unaged_0_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_0/T_25/M1_Mixed_Unaged_R0_T25.mat', struct_as_record=True, simplify_cells=True)
M1_mixed_unaged_0_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_0/T_40/M1_Mixed_Unaged_R0_T40.mat', struct_as_record=True, simplify_cells=True)

#r1
M2_mixed_unaged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_1/T_10/M2_Mixed_Unaged_R1_T10.mat', struct_as_record=True, simplify_cells=True)
M2_mixed_unaged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_1/T_25/M2_Mixed_Unaged_R1_T25.mat', struct_as_record=True, simplify_cells=True)
M2_mixed_unaged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_1/T_40/M2_Mixed_Unaged_R1_T40.mat', struct_as_record=True, simplify_cells=True)

#r3
M2_mixed_unaged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_3/T_10/M2_Mixed_Unaged_R3_T10.mat', struct_as_record=True, simplify_cells=True)
M1_mixed_unaged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_3/T_25/M1_Mixed_Unaged_R3_T25.mat', struct_as_record=True, simplify_cells=True)
M2_mixed_unaged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/Mixed_cells/Unaged/R_3/T_40/M2_Mixed_Unaged_R3_T40.mat', struct_as_record=True, simplify_cells=True)

#NCA cells

#aged

#r0
M1_nca_aged_0_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_0/T_10/M1_NCA_Aged_R0_T10.mat', struct_as_record=True, simplify_cells=True)
M1_nca_aged_0_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_0/T_25/M1_NCA_Aged_R0_T25.mat', struct_as_record=True, simplify_cells=True)
M1_nca_aged_0_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_0/T_40/M1_NCA_Aged_R0_T40.mat', struct_as_record=True, simplify_cells=True)

#r1
M2_nca_aged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_1/T_10/M2_NCA_Aged_R1_T10.mat', struct_as_record=True, simplify_cells=True)
M2_nca_aged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_1/T_25/M2_NCA_Aged_R1_T25.mat', struct_as_record=True, simplify_cells=True)
M2_nca_aged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_1/T_40/M2_NCA_Aged_R1_T40.mat', struct_as_record=True, simplify_cells=True)

#r3
M1_nca_aged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_3/T_10/M1_NCA_Aged_R3_T10.mat', struct_as_record=True, simplify_cells=True)
M2_nca_aged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_3/T_25/M2_NCA_Aged_R3_T25.mat', struct_as_record=True, simplify_cells=True)
M1_nca_aged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Aged/R_3/T_40/M1_NCA_Aged_R3_T40.mat', struct_as_record=True, simplify_cells=True)

#unaged

#r0
M1_nca_unaged_0_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_0/T_10/M1_NCA_Unaged_R0_T10.mat', struct_as_record=True, simplify_cells=True)
M1_nca_unaged_0_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_0/T_25/M1_NCA_Unaged_R0_T25.mat', struct_as_record=True, simplify_cells=True)
M1_nca_unaged_0_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_0/T_40/M1_NCA_Unaged_R0_T40.mat', struct_as_record=True, simplify_cells=True)

#r1
M2_nca_unaged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_1/T_10/M2_NCA_Unaged_R1_T10.mat', struct_as_record=True, simplify_cells=True)
M2_nca_unaged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_1/T_25/M2_NCA_Unaged_R1_T25.mat', struct_as_record=True, simplify_cells=True)
M2_nca_unaged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_1/T_40/M2_NCA_Unaged_R1_T40.mat', struct_as_record=True, simplify_cells=True)

#r3
M1_nca_unaged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_3/T_10/M1_NCA_Unaged_R3_T10.mat', struct_as_record=True, simplify_cells=True)
M1_nca_unaged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_3/T_25/M1_NCA_Unaged_R3_T25.mat', struct_as_record=True, simplify_cells=True)
M2_nca_unaged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NCA_cells/Unaged/R_3/T_40/M2_NCA_Unaged_R3_T40.mat', struct_as_record=True, simplify_cells=True)

#NMC cells

#aged

#r0
M1_nmc_aged_0_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_0/T_10/M1_NMC_Aged_R0_T10.mat', struct_as_record=True, simplify_cells=True)
M1_nmc_aged_0_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_0/T_25/M1_NMC_Aged_R0_T25.mat', struct_as_record=True, simplify_cells=True)
M1_nmc_aged_0_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_0/T_40/M1_NMC_Aged_R0_T40.mat', struct_as_record=True, simplify_cells=True)

#r1
M2_nmc_aged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_1/T_10/M2_NMC_Aged_R1_T10.mat', struct_as_record=True, simplify_cells=True)
M2_nmc_aged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_1/T_25/M2_NMC_Aged_R1_T25.mat', struct_as_record=True, simplify_cells=True)
M1_nmc_aged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_1/T_40/M1_NMC_Aged_R1_T40.mat', struct_as_record=True, simplify_cells=True)

#r3
M2_nmc_aged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_3/T_10/M2_NMC_Aged_R3_T10.mat', struct_as_record=True, simplify_cells=True)
M2_nmc_aged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_3/T_25/M2_NMC_Aged_R3_T25.mat', struct_as_record=True, simplify_cells=True)
M2_nmc_aged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Aged/R_3/T_40/M2_NMC_Aged_R3_T40.mat', struct_as_record=True, simplify_cells=True)

#unaged

#r0
M1_nmc_unaged_0_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_0/T_10/M1_NMC_Unaged_R0_T10.mat', struct_as_record=True, simplify_cells=True)
M1_nmc_unaged_0_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_0/T_25/M1_NMC_Unaged_R0_T25.mat', struct_as_record=True, simplify_cells=True)
M1_nmc_unaged_0_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_0/T_40/M1_NMC_Unaged_R0_T40.mat', struct_as_record=True, simplify_cells=True)

#r1
M2_nmc_unaged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_1/T_10/M2_NMC_Unaged_R1_T10.mat', struct_as_record=True, simplify_cells=True)
M2_nmc_unaged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_1/T_25/M2_NMC_Unaged_R1_T25.mat', struct_as_record=True, simplify_cells=True)
M2_nmc_unaged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_1/T_40/M2_NMC_Unaged_R1_T40.mat', struct_as_record=True, simplify_cells=True)

#r3
M1_nmc_unaged_1_10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_3/T_10/M1_NMC_Unaged_R3_T10.mat', struct_as_record=True, simplify_cells=True)
M1_nmc_unaged_1_25 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_3/T_25/M1_NMC_Unaged_R3_T25.mat', struct_as_record=True, simplify_cells=True)
M1_nmc_unaged_1_40 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/3_Module_level_experiments_fixed/Processed_data/NMC_cells/Unaged/R_3/T_40/M1_NMC_Unaged_R3_T40.mat', struct_as_record=True, simplify_cells=True)

# %% [markdown]
# <h4> hall sensor calibration

# %%
H1_calibration = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/2_Hall_sensors_calibration/H1_Calibration_struct.mat', struct_as_record=True, simplify_cells=True)
H2_calibration = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/2_Hall_sensors_calibration/H2_Calibration_struct.mat', struct_as_record=True, simplify_cells=True)
H3_calibration = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/2_Hall_sensors_calibration/H3_Calibration_struct.mat', struct_as_record=True, simplify_cells=True)
H4_calibration = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/2_Hall_sensors_calibration/H4_Calibration_struct.mat', struct_as_record=True, simplify_cells=True)
H5_calibration = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/2_Hall_sensors_calibration/H5_Calibration_struct.mat', struct_as_record=True, simplify_cells=True)
H6_calibration = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/2_Hall_sensors_calibration/H6_Calibration_struct.mat', struct_as_record=True, simplify_cells=True)
H7_calibration = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/2_Hall_sensors_calibration/H7_Calibration_struct.mat', struct_as_record=True, simplify_cells=True)
H8_calibration = loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/2_Hall_sensors_calibration/H8_Calibration_struct.mat', struct_as_record=True, simplify_cells=True)

# %% [markdown]
# <h4> single cell characterization

# %%
GS3 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/Aged_cells/HPPC_MS/HPPC_MultiSine_GS3.mat')
Y1= sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/Aged_cells/HPPC_MS/HPPC_MultiSine_Y1.mat')

OGS3 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/Aged_cells/Pseudo_OCV/OCVDis_GS3.mat')
OY1 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/Aged_cells/Pseudo_OCV/OCVDis_Y1.mat')

# %%
F1 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F1.mat')
F2 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F2.mat')
F3 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F3.mat')
F4 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F4.mat')
F5 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F5.mat')
F6 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F6.mat')
F7 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F7.mat')
F8 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F8.mat')
F9 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F9.mat')
F10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F10.mat')
F11 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F11.mat')
F12 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F12.mat')
F13 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F13.mat')
F14 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F14.mat')
F15 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F15.mat')
F16 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F16.mat')
F17 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F17.mat')
F18 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/HPPC_MS/HPPC_MultiSine_F18.mat')

# %%
OF1 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F1.mat')
OF2 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F2.mat')
OF3 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F3.mat')
OF4 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F4.mat')
OF5 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F5.mat')
OF6 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F6.mat')
OF7 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F7.mat')
OF8 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F8.mat')
OF9 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F9.mat')
OF10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F10.mat')
OF11 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F11.mat')
OF12 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F12.mat')
OF13 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F13.mat')
OF14 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F14.mat')
OF15 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F15.mat')
OF16 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F16.mat')
OF17 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F17.mat')
OF18 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NCA_cells/Pseudo_OCV/OCVDis_F18.mat')

# %%
P2 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P2.mat')
P3 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P3.mat')
P4 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P4.mat')
P5 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P5.mat')
P6 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P6.mat')
P7 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P7.mat')
P8 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P8.mat')
P9 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P9.mat')
P10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P10.mat')
P11 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P11.mat')
P12 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P12.mat')
P13 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P13.mat')
P14 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P14.mat')
P15 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P15.mat')
P16 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P16.mat')
P17 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P17.mat')
P18 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P18.mat')
P19 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P19.mat')
P20 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/HPPC_MS/HPPC_MultiSine_P20.mat')

# %%
OP2 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P2.mat')
OP3 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P3.mat')
OP4 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P4.mat')
OP5 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P5.mat')
OP6 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P6.mat')
OP7 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P7.mat')
OP8 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P8.mat')
OP9 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P9.mat')
OP10 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P10.mat')
OP11 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P11.mat')
OP12 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P12.mat')
OP13 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P13.mat')
OP14 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P14.mat')
OP15 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P15.mat')
OP16 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P16.mat')
OP17 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P17.mat')
OP18 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P18.mat')
OP19 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P19.mat')
OP20 = sio.loadmat('../../Data/imbalanced performance/Full factorial design of experiments dataset for parallel-connected lithium-ion cells imbalanced performance investigation/Parallel-connected module experimental campaign/1_Single_cell_characterisation/NMC_cells/Pseudo_OCV/OCVDis_P20.mat')

# %% [markdown]
# <h3> Merging the datasets

# %%
#as experiment
# TestID | CellPos | CycleIndex | Feature1 | Feature2 | ... | Chemistry | Aged | Temp | R_int for example

# %%
#as cycle

# %%
#as step
